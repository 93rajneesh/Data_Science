# %% [markdown]
# Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Line Plot:A Line Plot Is The Simplest Plot In All Plotting Types, As It Is The Visualization Of A Single Function. This Plot Helps Us To See The Relationship Between X-Axis, Y-Axis And It Also Takes Some Parameters Such As Hue, Size, Color, Etc.
# used to display several dependent variables against one independent variable.

# %%
sns.lineplot(x = iris.sepal_length , y =iris.sepal_width, color = "indianred" )
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,9]
sns.lineplot(x = x,y = y, color = "red")
# Out:
# <Axes: >

# %% [markdown]
# Count Plot:
#
# A Count Plot Is Used To Show The Counts Of Observations In Each Categorical Bin Using Bars.
#
# This Method Is Accepting The Parameters X, Y  Which Take The Name Of A Variable In Data, Hue It Is An Optional Parameter It Helps To Take Column Name For Color Encoding. Data Is Also An Optional Parameter That Takes DataFrame, Array, Or List Of Arrays, Dataset For Plotting.
#
# use:The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable. It uses the concept of a bar chart for the visual depiction.

# %%
tita = sns.load_dataset("titanic")
tita
sns.countplot(x = "sex" , data = tita)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# Bar Plot
# A Bar Chart Is A Way Of Comparing A Set Of Categorical Data. It Is Better To Convert Continuous Data To Bins Before Plotting. The Bar Chart Displays Data
#
# Using Several Bars, Each Representing A Particular Category. This Method Is Accepting The Parameters X, Y  Which Take The Name Of A Variable In Data, Hue It Is An Optional Parameter It Helps To Take Column Name For Color Encoding.
# use: The bar graph is used to compare the items between different groups over time. Bar graphs are used to measure the changes over a period of time. When the changes are larger, a bar graph is the best option to represent the data.

# %%
tita
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot( x = tita['sex'] , y = tita['age'], data = tita)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# Pair Plot
# Pair Plot Creates A Grid Of Axis Such That Each Numeric Variable In Data Will Create A Plot Between Each Other The Y-Axis Across A Single Row And The X-Axis Across A Single Column. The Diagonal Plots Are A Univariate Distribution Plot That Helps To Draw The Marginal Distribution Of The Data In Each Column.
#
# A Pair Plot Pairwise Relationships With Other Columns In The Data Frame And Also Plot Pair Plot With Itself.
# use:

# %%
sns.pairplot(tita)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %% [markdown]
# Scatter Plot
# Scatter Plot Is The Same As A Line Plot, In A Line Plot Instead Of Points Being Joined By Line Segments, The Points Are Shown Individually With A Dot, Circle, Or Any Other Shape. The Position Of Each Marker On The Horizontal And Vertical Axis Indicates Values For An Individual Data Point. This Plot Is Used To Observe Relationships Between Variables.
#
# This Method Is Accepting The Parameters X, Y  Which Take The Name Of A Variable In Data, Hue It Is An Optional Parameter It Helps To Take Column Name For Color Encoding. Marker Is A Parameter That Is Used To Change The Shape Of The Point Which Is Shown In The Plot.

# %%
sns.scatterplot(x = tita.fare , y = tita.age , color = "yellow" , marker="v" )
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %% [markdown]
# The seaborn.relplot() method of the Seaborn library is used to plot the relation between two variables of a dataset on a graph(x-y axis) with semantic mappings of subset.
#
# For example, there is a dataset with multiple variables such as age, height and gender. Let the x and y variables for the graph be age and height. Using seaborn library we can plot the relation between age and height and also the graph of age-height in relation to the gender.
#
# Syntax
#
# seaborn.relplot() method.
#
# seaborn.relplot(*, x=None, y=None, hue=None, size=None, style=None, data=No

# %%
sns.relplot(data = iris , x = "sepal_length" , y = "sepal_width" , hue = "species" , kind = "line" ,                          )

# %% [markdown]
# Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
# "timepoint" and y = "signal" for different events and regions.

# %%
fmri = sns.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot( data = fmri , x ="timepoint", y ="signal" , hue="event" , style = "region")
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
# 'pclass', y = 'age' and y = 'fare'.

# %%
ttn = sns.load_dataset("titanic")
ttn
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# seaborn.boxplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None, **kwargs)

# %%
# https://seaborn.pydata.org/generated/seaborn.boxplot.html

sns.boxplot( data = ttn , x  = "pclass" , y = "age" )
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot( data = ttn , x  = "pclass" , y = "age" , hue = "sex" ,color="red")
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %% [markdown]
# Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
# parameter for the 'cut' column of the diamonds dataset.

# %%
dia = sns.load_dataset("diamonds")
dia
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.histplot(data = dia , y = "price" , hue = "cut" , element = "step")
# Out:
# <Axes: xlabel='Count', ylabel='price'>

# %% [markdown]
# Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
# of the iris dataset.

# %%
iris1 = sns.load_dataset("iris")
iris1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot( data = iris1 , hue = "species")

# %% [markdown]
# Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %% [markdown]
# eatmap is defined as a graphical representation of data using colors to visualize the value of the matrix. In this, to represent more common values or higher activities brighter colors basically reddish colors are used and to represent less common or activity values, darker colors are preferred. Heatmap is also defined by the name of the shading matrix. Heatmaps in Seaborn can be plotted by using the seaborn.heatmap() function
#
#
#
# Important Parameters:
#
# data: 2D dataset that can be coerced into an ndarray.
#
# vmin, vmax: Values to anchor the colormap, otherwise they are inferred from the data and other keyword arguments.
#
# cmap: The mapping from data values to color space.
#
# center: The value at which to center the colormap when plotting divergent data.
#
# annot: If True, write the data value in each cell.
#
# fmt: String formatting code to use when adding annotations.
#
#
# linewidths: Width of the lines that will divide each cell.
#
# linecolor: Color of the lines that will divide each cell.
#
# cbar: Whether to draw a colorbar.

# %% [markdown]
# annot=True: This parameter determines whether to annotate the heatmap with the data values. Setting it to True will display the actual data values on each cell of the heatmap.
#
# fmt="d": This parameter specifies the format string for the annotations. In this case, d stands for integer formatting. It means that the data values will be displayed as integers without any decimal places.
#
# cmap='YlGnBu': This parameter sets the color map to be used for the heatmap. The color map determines the colors that will be used to represent different values in the heatmap. In this case, 'YlGnBu' refers to the Yellow-Green-Blue color map

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# he heatmap requires a numerical matrix as input, where each cell represents a value to be color-coded.
# pivot() function is used to reshape the 'flights' dataset into a pivot table, where the rows represent months, the columns represent years, and the values represent the number of passengers. 

flights = sns.load_dataset('flights').pivot('month', 'year', 'passengers')
sns.heatmap(data= flights , annot=True, fmt="d", cmap='YlGnBu')
plt.xlabel('Year')
plt.ylabel('Month')
plt.title('Passenger Flights')
# Out:
# <ipython-input-121-7e7c63c9d47b>:6: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = sns.load_dataset('flights').pivot('month', 'year', 'passengers')
# Text(0.5, 1.0, 'Passenger Flights')
