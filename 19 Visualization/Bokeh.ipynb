# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
# !pip install bokeh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bokeh.plotting import figure, output_file , show
from bokeh.sampledata.iris import flowers
# it render output in html format
output_file('test.html')

p = figure(title = "test flower")
p.xaxis.axis_label = "petal length"
p.yaxis.axis_label = "petal width"
# circle: it help to plot 
p.circle(flowers['petal_length'] , flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="53045e53-4133-4e19-adcb-b44bb8d06917" data-root-id="2066"></div>

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# print line graph
x = [2,4,2,8,10]
y = [1,3,2,7,9]
output_file("line.html")
p1 = figure(title = "line plot")
p1.line(x,y)
show(p1)
# Out:
#   <div class="bk-root" id="d7d7364a-bd88-47ee-b3ff-5b999e310148" data-root-id="2346"></div>

# %%
from bokeh.models.plots import Legend
# from bokeh.plotting import figure, output_file, show
x = [2,4,2,8,10]
y = [1,3,2,7,9]
output_file("line.html")
p1 = figure(title = "line plot" )
p1.scatter(x,y , fill_color = 'red' ,legend_label = 'red points' , size = 20)
show(p1)
# Out:
#   <div class="bk-root" id="a8022e67-d3d6-4c68-b8e5-7d03ea345ae5" data-root-id="2774"></div>

# %%
# # print scatter graph
# x2 = [2,4,2,8,10]
# y2= [1,3,2,7,9]
# output_file("scatter.html")
# p2 = figure(title = "scatter plot")
# p.scatter(x2,y2 , fill_color = 'red')

# show(p2)

from bokeh.plotting import figure, output_file, show

x2 = [2, 4, 2, 8, 10]
y2 = [1, 3, 2, 7, 9]

output_file("scatter.html")
p2 = figure(title="scatter plot")
p2.scatter(x2, y2, fill_color='blue' )

show(p2)
# Out:
#   <div class="bk-root" id="e6d0e38c-a182-4c38-a706-d359f88edb21" data-root-id="8308"></div>

# %%
from bokeh.plotting import figure, output_file, show
# Out:
#   <div class="bk-root" id="ae8a084c-790f-4e26-8f44-27835353ad5a" data-root-id="1751"></div>

# %%
# Out:
#   <div class="bk-root" id="ff3b398e-9e40-4d8f-b3ed-9daf27acece5" data-root-id="7458"></div>
