# %%
import pandas as pd

# %%
df = pd.read_csv("https://gist.githubusercontent.com/jwalsh/ce1dc0436aba5b7a5c9666f47fa5a380/raw/5ce3854392b43ff97907112d344fc008229b0445/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                            Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# ...

# %%
# type of data 
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Lname           object
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# statical data gives
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
# find the data type - object
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Lname           True
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
# filter out object datatype
# o/p - in series and data type is series.
# convert series to index .index are used
# index refers as column name
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Lname', 'Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
type(df.dtypes[df.dtypes == 'object'])
# Out:
# pandas.core.series.Series

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#             Lname              Name   Sex Ticket        Cabin Embarked
# count         156               156   156    156           31      155
# unique        141               152     2    145           28        3
# top     Andersson   Miss. Elizabeth  male   2651  C23 C25 C27        S
# freq            4                 2   100      2            2      110

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Lname           object
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes[df.dtypes == 'int64'].index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], dtype='object')

# %%
# format of discribe
# df.discribe
df[df.dtypes[df.dtypes == 'int64'].index].describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean     78.500000    0.346154    2.423077    0.615385    0.397436
# std      45.177428    0.477275    0.795459    1.056235    0.870146
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%      39.750000    0.000000    2.000000    0.000000    0.000000
# 50%      78.500000    0.000000    3.000000    0.000000    0.000000
# 75%     117.250000    1.000000    3.000000    1.000000    0.000000
# max     156.000000    1.000000    3.000000    5.000000    5.000000

# %%
# check datatype
df[df.dtypes[df.dtypes == 'float64'].index].count()
# Out:
# Age     126
# Fare    156
# dtype: int64

# %%
df[df.dtypes[df.dtypes == 'float64'].index].describe()
# Out:
#               Age        Fare
# count  126.000000  156.000000
# mean    28.141508   28.109587
# std     14.613880   39.401047
# min      0.830000    6.750000
# 25%     19.000000    8.003150
# 50%     26.000000   14.454200
# 75%     35.000000   30.371850
# max     71.000000  263.000000

# %%
df[df.dtypes[df.dtypes == 'float64'].index].convert_dtypes('string')
# Out:
#       Age     Fare
# 0    22.0     7.25
# 1    38.0  71.2833
# 2    26.0    7.925
# 3    35.0     53.1
# 4    35.0     8.05
# ..    ...      ...
# 151  22.0     66.6
# 152  55.5     8.05
# 153  40.5     14.5
# 154  <NA>   7.3125
# 155  51.0  61.3792
#
# [156 rows x 2 columns]

# %%
# check datatype
df[df.dtypes[df.dtypes == 'float64'].index].dtypes
# Out:
# Age     float64
# Fare    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Lname', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=156, step=1)

# %%
df[['Age']]
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 151  22.0
# 152  55.5
# 153  40.5
# 154   NaN
# 155  51.0
#
# [156 rows x 1 columns]

# %%
df[['Ticket','Age']][5:17:2]
# Out:
#     Ticket   Age
# 5   330877   NaN
# 7   349909   2.0
# 9   237736  14.0
# 11  113783  58.0
# 13  347082  39.0
# 15  248706  55.0

# %%
# create new column in given data and assign zero value
df['new_col'] = 0

# %%
df
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
# Note: can only concatenate str (not "float") to str

df['new_Col1'] = df['Pclass'] + df['Age']

# %%
df
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
df['new_col2'] = df['Lname'] + df['Name']

# %%
df
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
# find unique category(or value) in particular class
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df['Age'])
# Out:
# [22.0, 38.0, 26.0, 35.0, 35.0, ..., 22.0, 55.5, 40.5, NaN, 51.0]
# Length: 156
# Categories (56, float64): [0.83, 2.00, 3.00, 4.00, ..., 65.0, 66.0, 70.5, 71.0]

# %%
pd.Categorical(df['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., 'C2', NaN, NaN, NaN, NaN]
# Length: 156
# Categories (28, object): ['A5', 'A6', 'B28', 'B30', ..., 'F G73', 'F2', 'F33', 'G6']

# %%
# filter the dATASET Acc. to condition
# o/p - bool
df['Age'] >18
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 151     True
# 152     True
# 153     True
# 154    False
# 155     True
# Name: Age, Length: 156, dtype: bool

# %%
# o/p- filter dataset
df[df['Age'] >18]
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 150          151         0       2       Bateman
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
len(df[df['Age']>18]) -155
# Out:
# -56

# %%
# findout howmuch people pay above average value(28.109587)
df[df['Fare'] > 28.109587]
# Out:
#      PassengerId  Survived  Pclass        Lname  \
# 1              2         1       1      Cumings
# 3              4         1       1     Futrelle
# 6              7         0       1     McCarthy
# 9             10         1       2       Nasser
# 13            14         0       3    Andersson
# 16            17         0       3         Rice
# 23            24         1       1       Sloper
# 25            26         1       3      Asplund
# 27            28         0       1      Fortune
# 31            32         1       1      Spencer
# 34            35         0       1        Meyer
# 35            36         0       1    Holverson
# 43            44         1       2      Laroche
# 50            51         0       3       Panula
# 52            53         1       1       Harper
# 54            55         0       1        Ostby
# 55            56         1       1      Woolner
# 59            60         0       3      Goodwin
# ...

# %%
len(df[df['Fare'] > 28.109587 ])
# Out:
# 43

# %%
# get free fare
df[df['Fare'] == 0]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Lname, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, new_col, new_Col1, new_col2]
# Index: []

# %%
len(df[df['Fare'] == 0])
# Out:
# 0

# %%
# how many people survived in tiatanic disaster
df[df['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass          Lname  \
# 1              2         1       1        Cumings
# 2              3         1       3      Heikkinen
# 3              4         1       1       Futrelle
# 8              9         1       3        Johnson
# 9             10         1       2         Nasser
# 10            11         1       3      Sandstrom
# 11            12         1       1        Bonnell
# 15            16         1       2        Hewlett
# 17            18         1       2       Williams
# 19            20         1       3     Masselmani
# 21            22         1       2        Beesley
# 22            23         1       3        McGowan
# 23            24         1       1         Sloper
# 25            26         1       3        Asplund
# 28            29         1       3        O'Dwyer
# 31            32         1       1        Spencer
# 32            33         1       3          Glynn
# 36            37         1       3          Mamee
# ...

# %%
len(df[df['Survived'] == 1])
# Out:
# 54

# %%
# find the male and female survived
df[(df['Survived'] == 1) & (df['Sex'] == 'female')]
# Out:
#      PassengerId  Survived  Pclass          Lname  \
# 1              2         1       1        Cumings
# 2              3         1       3      Heikkinen
# 3              4         1       1       Futrelle
# 8              9         1       3        Johnson
# 9             10         1       2         Nasser
# 10            11         1       3      Sandstrom
# 11            12         1       1        Bonnell
# 15            16         1       2        Hewlett
# 19            20         1       3     Masselmani
# 22            23         1       3        McGowan
# 25            26         1       3        Asplund
# 28            29         1       3        O'Dwyer
# 31            32         1       1        Spencer
# 32            33         1       3          Glynn
# 39            40         1       3  Nicola-Yarred
# 43            44         1       2        Laroche
# 44            45         1       3        Devaney
# 47            48         1       3     O'Driscoll
# ...

# %%
len(df[(df['Survived'] == 1) & (df['Sex'] == 'Female')])
# Out:
# 0

# %%
# find person who pay maximum fare
df['Fare'] == max(df['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Fare, Length: 156, dtype: bool

# %%
df[df['Fare'] == max(df['Fare'])]
# Out:
#     PassengerId  Survived  Pclass    Lname                    Name     Sex  \
# 27           28         0       1  Fortune   Mr. Charles Alexander    male
# 88           89         1       1  Fortune       Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked  new_col  new_Col1  \
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S        0      20.0
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S        0      24.0
#
#                          new_col2
# 27  Fortune Mr. Charles Alexander
# 88      Fortune Miss. Mabel Helen

# %%
# row 0 to 3
df[0:6]
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
# 5            6         0       3      Moran
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                            Mr. William Henry    male  35.0      0      0
# 5                                    Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked  new_col  new_Col1  \
# ...

# %%
# find passerId , survived and pclass at  3,4,5 position
df[['PassengerId' , 'Survived' ,'Pclass',	'Lname']][3:6]
# Out:
#    PassengerId  Survived  Pclass     Lname
# 3            4         1       1  Futrelle
# 4            5         0       3     Allen
# 5            6         0       3     Moran

# %%
# iloc = location
# iloc: it takes inbuid index(ex: 0,1,2)
df.iloc[0:2]
# Out:
#    PassengerId  Survived  Pclass    Lname  \
# 0            1         0       3   Braund
# 1            2         1       1  Cumings
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
#
#       Ticket     Fare Cabin Embarked  new_col  new_Col1  \
# 0  A/5 21171   7.2500   NaN        S        0      25.0
# 1   PC 17599  71.2833   C85        C        0      39.0
#
#                                             new_col2
# 0                             Braund Mr. Owen Harris
# 1  Cumings Mrs. John Bradley (Florence Briggs Tha...

# %%
# iloc: it takes inbuild index(ex: 0,1,2)
# ex: give the value from 0 to 5(column) of the first three rows ,started from zero
df.iloc[0:5,[0,1,2,3]] 

# ['PassengerId' , 'Survived' ,'Pclass',	'Lname']
# Out:
#    PassengerId  Survived  Pclass      Lname
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen

# %%
# use of loc
df.loc[0:5,['PassengerId' , 'Survived' ,'Pclass',	'Lname']]
# Out:
#    PassengerId  Survived  Pclass      Lname
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
# 5            6         0       3      Moran
